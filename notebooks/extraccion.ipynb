# %%
import sys
import os
sys.path.append(os.path.abspath(".."))


import pandas as pd
from src.extraccion import descargarDatosSecop
from src.conexionDB import getEngine
from src.conexionDB import cargarDatosCrudos

# %%
dataSecop = descargarDatosSecop()
dataSecop.shape
# Out:
# WARNING:root:Requests made without an app_token will be subject to strict throttling limits.
# Descargando registros desde offset 0...
# Descargando registros desde offset 10000...
# Descargando registros desde offset 20000...
# Descargando registros desde offset 30000...
# Descargando registros desde offset 40000...
# Descargando registros desde offset 50000...
# Descargando registros desde offset 60000...
# Descargando registros desde offset 70000...
# Descargando registros desde offset 80000...
# Descargando registros desde offset 90000...
# Descargando registros desde offset 100000...
# Descargando registros desde offset 110000...
# Descargando registros desde offset 120000...
# Descargando registros desde offset 130000...
# Descargando registros desde offset 140000...
# Descargando registros desde offset 150000...
# Descargando registros desde offset 160000...
# Descargando registros desde offset 170000...
# Descargando registros desde offset 180000...
# Descargando registros desde offset 190000...
# Descargando registros desde offset 200000...
# Descargando registros desde offset 210000...
# Descargando registros desde offset 220000...
# Descargando registros desde offset 230000...
# Descargando registros desde offset 240000...
# Descargando registros desde offset 250000...
# Descargando registros desde offset 260000...
# Descargando registros desde offset 270000...
# Descargando registros desde offset 280000...
# Descargando registros desde offset 290000...
# Descargando registros desde offset 300000...
# Descargando registros desde offset 310000...
# Descargando registros desde offset 320000...
# Descargando registros desde offset 330000...
# Descargando registros desde offset 340000...
# Descargando registros desde offset 350000...
# Descargando registros desde offset 360000...
# Descargando registros desde offset 370000...
# Descargando registros desde offset 380000...
# Descargando registros desde offset 390000...
# Descargando registros desde offset 400000...
# Descargando registros desde offset 410000...
# Descargando registros desde offset 420000...
# Descargando registros desde offset 430000...
# Descargando registros desde offset 440000...
# Descargando registros desde offset 450000...
# Descargando registros desde offset 460000...
# Descargando registros desde offset 470000...
# Descargando registros desde offset 480000...
# Descargando registros desde offset 490000...
# Descargando registros desde offset 500000...
# Descargando registros desde offset 510000...
# Descargando registros desde offset 520000...
# Descargando registros desde offset 530000...
# Descargando registros desde offset 540000...
# Descargando registros desde offset 550000...
# Descargando registros desde offset 560000...
# Descargando registros desde offset 570000...
# Descargando registros desde offset 580000...
# Descargando registros desde offset 590000...
# Descargando registros desde offset 600000...
# Descargando registros desde offset 610000...
# Descargando registros desde offset 620000...
# Descargando registros desde offset 630000...
# Descargando registros desde offset 640000...
# Descargando registros desde offset 650000...
# Descargando registros desde offset 660000...
# Descargando registros desde offset 670000...
# Descargando registros desde offset 680000...
# Descargando registros desde offset 690000...
# Descargando registros desde offset 700000...
# Descargando registros desde offset 710000...
# Descargando registros desde offset 720000...
# Descargando registros desde offset 730000...
# Descargando registros desde offset 740000...
# Descargando registros desde offset 750000...
# Descargando registros desde offset 760000...
# Descargando registros desde offset 770000...
# Descargando registros desde offset 780000...
# Descargando registros desde offset 790000...
# Descargando registros desde offset 800000...
# Descargando registros desde offset 810000...
# Descargando registros desde offset 820000...
# Descargando registros desde offset 830000...
# Descargando registros desde offset 840000...
# Descargando registros desde offset 850000...
# Descargando registros desde offset 860000...
# Descargando registros desde offset 870000...
# Descargando registros desde offset 880000...
# Descargando registros desde offset 890000...
# Descargando registros desde offset 900000...
# Descargando registros desde offset 910000...
# Descargando registros desde offset 920000...
# Descargando registros desde offset 930000...
# Descargando registros desde offset 940000...
# Descargando registros desde offset 950000...
# Descargando registros desde offset 960000...
# Descargando registros desde offset 970000...
# Descargando registros desde offset 980000...
# Descargando registros desde offset 990000...
# Descargando registros desde offset 1000000...
# Descargando registros desde offset 1010000...
# Descargando registros desde offset 1020000...
# Descargando registros desde offset 1030000...
# Descargando registros desde offset 1040000...
# Descargando registros desde offset 1050000...
# Descargando registros desde offset 1060000...
# Descargando registros desde offset 1070000...
# Descargando registros desde offset 1080000...
# Descargando registros desde offset 1090000...
# Descargando registros desde offset 1100000...
# Descargando registros desde offset 1110000...
# Descargando registros desde offset 1120000...
# Descargando registros desde offset 1130000...
# Descargando registros desde offset 1140000...
# Descargando registros desde offset 1150000...
# Descargando registros desde offset 1160000...
# Descargando registros desde offset 1170000...
# Descargando registros desde offset 1180000...
# Descargando registros desde offset 1190000...
# Descargando registros desde offset 1200000...
# Descargando registros desde offset 1210000...
# Descargando registros desde offset 1220000...
# Descargando registros desde offset 1230000...
# Descargando registros desde offset 1240000...
# Descargando registros desde offset 1250000...
# Descargando registros desde offset 1260000...
# Descargando registros desde offset 1270000...
# Descargando registros desde offset 1280000...
# Descargando registros desde offset 1290000...
# Descargando registros desde offset 1300000...
# Descargando registros desde offset 1310000...
# Descargando registros desde offset 1320000...
# Descargando registros desde offset 1330000...
# Descargando registros desde offset 1340000...
# Descargando registros desde offset 1350000...
# Descargando registros desde offset 1360000...
# Descargando registros desde offset 1370000...
# Descargando registros desde offset 1380000...
# Descargando registros desde offset 1390000...
# Descargando registros desde offset 1400000...
# Descargando registros desde offset 1410000...
# Descargando registros desde offset 1420000...
# Descargando registros desde offset 1430000...
# Descargando registros desde offset 1440000...
# Descargando registros desde offset 1450000...
# Descargando registros desde offset 1460000...
# Descargando registros desde offset 1470000...
# Descargando registros desde offset 1480000...
# Descargando registros desde offset 1490000...
# Descargando registros desde offset 1500000...
# Descargando registros desde offset 1510000...
# Descargando registros desde offset 1520000...
# Descargando registros desde offset 1530000...
# Descargando registros desde offset 1540000...
# Descargando registros desde offset 1550000...
# Descargando registros desde offset 1560000...
# Descargando registros desde offset 1570000...
# Descargando registros desde offset 1580000...
# Descargando registros desde offset 1590000...
# Descargando registros desde offset 1600000...
# Descargando registros desde offset 1610000...
# Descargando registros desde offset 1620000...
# Descargando registros desde offset 1630000...
# Descargando registros desde offset 1640000...
# Descargando registros desde offset 1650000...
# Descargando registros desde offset 1660000...
# Descargando registros desde offset 1670000...
# Descargando registros desde offset 1680000...
# Descargando registros desde offset 1690000...
# (1681982, 22)

# %%
motor = getEngine()
cargarDatosCrudos(dataSecop, motor, "secop_contratos_2025")
