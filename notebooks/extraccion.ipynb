# %%
import sys
import os
sys.path.append(os.path.abspath(".."))


import pandas as pd
from src.extraccion import descargarDatosSecop
from src.conexionDB import getEngine
from src.conexionDB import cargarDatosCrudosSecop

# %%
dataSecop = descargarDatosSecop()
dataSecop.shape

# %%
motor = getEngine()
cargarDatosCrudosSecop(dataSecop, motor, "secop_contratos_2025")
